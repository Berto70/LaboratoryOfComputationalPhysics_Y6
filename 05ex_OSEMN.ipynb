# %% [markdown]
# # OSEMN Exercises

# %%
# %matplotlib inline
import pandas as pd
import numpy as np

# %% [markdown]
# 1\. Create a random list of number and then save it to a text file named "simple_data.txt"

# %% [markdown]
# 2\. Create a random matrix of 5x5 and then save it to a text file named "data.txt"

# %% [markdown]
# 3\. Load the saved txt file of point 2 and convert it to a csv file (by hand)

# %% [markdown]
# 4\. load the binary file named *credit_card.dat* and convert the data into the real credit-card number.
# Each line correspond to a credit card number.
# Each character is composed by 6 bit (even the space) and the last 4 bit are just a padding
#
# **hint**: use the `chr()` function to convert a number to a char

# %%
with open('./credit_card.dat', 'rb') as f: #rb is read binary
    data = f.readlines()

for row in data:
    for d in range(int((len(row)-4)/6)): #from tot len we remove last 4 bit of pad. the div by 6 to get how many numbers
        print(chr(int(row[d*6:d*6+6], 2)), end='') # for each row, we select each "number", by its index and it's lenght = 6 bits.
        #convert it to int from bin (,2) and then in chr. end='', to set up a new line
    print()
# Out:
# 7648 5673 3775 2271
# 3257 8247 3354 2266
# 2722 0001 4011 6652
# 0661 3063 3742 3150
# 0432 1608 1462 4742
# 5827 2027 8785 7303
# 5774 8528 2087 1117
# 8140 1210 6352 2845
# 5764 1133 7301 7100
# 6456 1737 4126 6726
# 1228 8631 7382 0000
# 7051 0160 5374 3166
# 0618 3587 1630 6376
# 1545 5454 7444 5636
# 6735 3116 3202 6834
# 7287 5011 1547 8413
# 7033 2607 3328 4200
# 2568 5244 1874 5024
# 1684 2253 7570 7118
# 0672 2576 0575 6631
# 6332 8353 8787 1340
# 1813 3361 1175 4211
# 2477 6450 8840 2368
# 5512 3505 2563 1326
# 3083 7882 0621 0025
# 4521 5148 8045 0334
# 7563 3654 8713 5787
# 8324 2664 0476 5561
# 0565 2504 7168 3510
# 5107 5507 1767 0738
# 2462 1821 2448 1443
# 2788 0638 6861 6554
# 5851 5873 5474 0547
# 0670 1004 4013 2655
# 5874 5506 3048 0806
# 2805 5401 8462 1260
# 5083 8406 6310 1862
# 1076 1445 3013 2266
# 8440 4804 4844 5277
# 4758 6141 0686 1387
# 7586 0675 0315 2568
# 2544 1258 7432 5165
# 3474 5023 4434 5626
# 1410 0270 0434 5086
# 7315 4446 1104 4215
# ...

# %% [markdown]
# 5\. Load the file "user_data.json", filter the data by the "CreditCardType" field equals to "American Express". Than save the data a to CSV.

# %%
import json
data_json = json.load(open('./user_data.json'))

filter_data = filter(lambda data_json: data_json['CreditCardType'] == 'American Express', data_json)

with open("./user_data_filtered.csv", 'w') as f:
    f.write("ID,JobTitle,EmailAddress,FirstNameLastName,CreditCard,CreditCardType\n")
    for row in filter_data:
        f.write(row['ID'] + "," + row['JobTitle'] + "," + row['EmailAddress'] + "," + row['FirstNameLastName'] + "," + row['CreditCard'] + ',' +row['CreditCardType'] + "\n")

# %% [markdown]
# 6\. Load the file from this url: [https://www.dropbox.com/s/7u3lm737ogbqsg8/mushrooms_categorized.csv?dl=1](https://www.dropbox.com/s/7u3lm737ogbqsg8/mushrooms_categorized.csv?dl=1) with Pandas.
# + Explore the data (see the info of the data)
# + Draw the istogram of the 'class' field. Decribe wath yuou see

# %%
data_1 = pd.read_csv('https://www.dropbox.com/s/7u3lm737ogbqsg8/mushrooms_categorized.csv?dl=1')
data_1.head(5)

data_1['class'].hist()
# Out:
# <Axes: >

# %% [markdown]
# 7\. Load the remote file [https://www.dropbox.com/s/vkl89yce7xjdq4n/regression_generated.csv?dl=1](https://www.dropbox.com/s/vkl89yce7xjdq4n/regression_generated.csv?dl=1) with Pandas and plot a scatter plot all possible combination of the following fields:
#
#   + features_1
#   + features_2
#   + features_3

# %%
import matplotlib.pyplot as plt
data_2 = pd.read_csv('https://www.dropbox.com/s/vkl89yce7xjdq4n/regression_generated.csv?dl=1')

feat_list = ['features_1', 'features_2', 'features_3']

fig, ax = plt.subplots(3, 3, figsize=(10, 10))

for i in range(3):
    for j in range(3):
        if i != j:
            ax[i,j].scatter(data_2[feat_list[i]], data_2[feat_list[j]], marker='.')
            # ax[i,i].scatter(regr_data[feat[i]], regr_data[feat[i]], color='orange')
            ax[i,j].set(xlabel=feat_list[i], ylabel=feat_list[j])

        else:
            ax[i,j].set_axis_off()

# %% [markdown]
# 8\. Load the same file of point 6, and convert the file to json with Pandas.

# %%
data_1 = pd.read_csv('https://www.dropbox.com/s/7u3lm737ogbqsg8/mushrooms_categorized.csv?dl=1')

data_1.to_json('./mushroom_categorized.json', orient='records')
